# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix

# %%
train_file_path = "C:/Users/Anshuman/Downloads/twitter_training.csv"
validation_file_path = "C:/Users/Anshuman/Downloads/twitter_validation.csv"

train_data = pd.read_csv(train_file_path)
validation_data = pd.read_csv(validation_file_path)

# %%
def safe_preprocess_text(text):
    if isinstance(text, str):
        text = text.lower()
        text = re.sub(r'http\S+|www\S+|https\S+', '', text, flags=re.MULTILINE)
        text = re.sub(r'\@\w+|\#','', text)
        text = re.sub(r'[^\w\s]', '', text)
        return text
    else:
        return ''

# %%
train_data['Processed_Text'] = train_data.iloc[:, 3].apply(safe_preprocess_text)
validation_data['Processed_Text'] = validation_data.iloc[:, 3].apply(safe_preprocess_text)

# %%
X_train = train_data['Processed_Text']
y_train = train_data.iloc[:, 2]
X_val = validation_data['Processed_Text']
y_val = validation_data.iloc[:, 2]

# %%
vectorizer = CountVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_val_vec = vectorizer.transform(X_val)

# %%
model = MultinomialNB()
model.fit(X_train_vec, y_train)
# Out:
# MultinomialNB()

# %%
y_pred = model.predict(X_val_vec)

print(classification_report(y_val, y_pred))
print(confusion_matrix(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#   Irrelevant       0.88      0.71      0.79       171
#     Negative       0.76      0.90      0.83       266
#      Neutral       0.93      0.74      0.83       285
#     Positive       0.79      0.91      0.84       277
#
#     accuracy                           0.83       999
#    macro avg       0.84      0.82      0.82       999
# weighted avg       0.84      0.83      0.82       999
#
# [[122  23   4  22]
#  [  3 240   7  16]
#  [  8  35 212  30]
#  [  5  16   5 251]]

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x=y_val)
plt.title('Sentiment Distribution in Validation Data')
plt.show()

# %%
plt.figure(figsize=(14, 8))
sns.countplot(x=validation_data.iloc[:, 1], hue=y_val)
plt.title('Sentiment by Topic/Brand in Validation Data')
plt.xticks(rotation=90)
plt.show()
